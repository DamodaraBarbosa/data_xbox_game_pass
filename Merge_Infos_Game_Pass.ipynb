# %% [markdown]
# <a href="https://colab.research.google.com/github/DamodaraBarbosa/infos_xbox_game_pass/blob/main/Merge_Infos_Game_Pass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as bibliotecas a serem utilizadas

# %%
import pandas as pd
import string

# %% [markdown]
# # Importando as bases de dados

# %%
# tabela com os jogos que estão ou estiveram no serviço Game Pass:

df_gamepass = pd.read_csv('/content/drive/MyDrive/Dados Xbox/Game Pass Master List - Master List (1).csv')
df_gamepass.columns = df_gamepass.iloc[0]
df_gamepass.drop([0], inplace= True)
df_gamepass.head()
# Out:
# 0                        Game     System xCloud       Status     Added  \
# 1         Persona 3: Portable  Xbox / PC    Yes  Coming Soon  Jan 2023
# 2           Persona 4: Golden  Xbox / PC    Yes  Coming Soon  Jan 2023
# 3                High on Life  Xbox / PC    Yes  Coming Soon  Dec 2022
# 4            Hello Neighbor 2  Xbox / PC    Yes  Coming Soon  Dec 2022
# 5  Warhammer 40,000: Darktide  Xbox / PC    Yes  Coming Soon  Nov 2022
#
# 0 Removed Months   Release    Age Metacritic Completion     Genre (Giantbomb)  \
# 1     NaN  -2.63  Nov 2009  13.22         89       65.5          Role-Playing
# 2     NaN  -2.63  Jun 2012  10.61         90       68.5                   NaN
# 3     NaN  -1.41  Dec 2022   0.00        NaN        NaN  First-Person Shooter
# 4     NaN  -1.18  Dec 2022   0.00        NaN        NaN     Strategy / Puzzle
# 5     NaN  -0.99  Nov 2022   0.00        NaN        NaN                Action
#
# 0 Xbox Series X|S Owner Notes  ESRB  \
# 1             NaN         NaN     M
# 2             NaN         NaN     M
# 3             NaN         NaN     M
# 4             NaN         NaN  E10+
# 5       Exclusive         NaN    RP
#
# 0                           ESRB Content Descriptors Public Notes Retail
# 1  Blood, Language, Partial Nudity, Sexual Themes...          NaN    NaN
# 2  Alcohol Reference, Animated Blood, Language, P...          NaN    NaN
# 3  Violence, Blood, Sexual Themes, Use of Drugs, ...          NaN    NaN
# 4                                      Mild Violence          NaN    NaN
# 5                                                NaN          NaN    NaN

# %%
df_gamepass.shape
# Out:
# (1185, 18)

# %%
# dataframe com a biblioteca de jogos do Xbox:

df_xbox_games = pd.read_csv('/content/drive/MyDrive/Dados Xbox/df_xbox_games.csv')
df_xbox_games.head()
# Out:
#                      name              genre(s)       developer(s)  \
# 0   0 Day Attack on Earth               Shooter              Gulti
# 1             007 Legends  First-person shooter            Eurocom
# 2  007: Quantum of Solace  First-person shooter           Treyarch
# 3           0-D Beat Drop       Puzzle & Trivia       Cyclone Zero
# 4               1 vs. 100                 Party  Xbox Game Studios
#
#         publisher(s)   releasedate  \
# 0        Square Enix  Dec 23, 2009
# 1         Activision  Oct 16, 2012
# 2         Activision   Nov 4, 2008
# 3   Arc System Works  Nov 11, 2009
# 4  Xbox Game Studios  Nov 19, 2009
#
#                                               addons
# 0  ['Xbox Live Arcade', 'Xbox One Backward Compat...
# 1                                                 []
# 2                                                 []
# 3                               ['Xbox Live Arcade']
# 4                               ['Xbox Live Arcade']

# %%
df_xbox_games.shape
# Out:
# (5141, 6)

# %%
# dataframe com dados oriundos do site True Achievements:

df_true_achievements = pd.read_csv('/content/drive/MyDrive/Dados Xbox/xbox_games_TA.csv')
df_true_achievements.head()
# Out:
#                            Name TA_Score Gamerscore Ratio  Gamers  Comp %  \
# 0  "ZAZEN", zen meditation game    3,234      1,000  3.23     199     3.5
# 1                        #IDARB    1,430      1,000  1.43  93,605    22.9
# 2                 #SinucaAttack    1,018      1,000  1.02   5,294    93.8
# 3                    >observer_    2,055      1,000  2.06  12,124     7.0
# 4                     0 Degrees    1,064      1,000  1.06   2,645    75.9
#
#      Comp time Rating
# 0          NaN      -
# 1    1-2 hours    2.7
# 2  0-0.5 hours    1.9
# 3  10-12 hours    3.4
# 4    1-2 hours    2.1

# %%
df_true_achievements.shape
# Out:
# (9306, 8)

# %%
# dataframe com dados do Metacritic dos jogos Xbox:

df_metacritic = pd.read_csv('/content/drive/MyDrive/Dados Xbox/xbox_games_metacritic.csv')
df_metacritic.head()
# Out:
#                                            Name   Release date Metascore  \
# 0          Indiana Jones and the Emperor's Tomb  June 11, 2019       tbd
# 1                    Tom Clancy's Splinter Cell  June 11, 2019       tbd
# 2                           Armed and Dangerous  June 11, 2019       tbd
# 3                   Sphinx and the Cursed Mummy  June 11, 2019       tbd
# 4  Tom Clancy's Splinter Cell: Pandora Tomorrow  June 11, 2019       tbd
#
#   Userscore
# 0       tbd
# 1       tbd
# 2       tbd
# 3       tbd
# 4       tbd

# %%
df_metacritic
# Out:
#                                               Name       Release date  \
# 0             Indiana Jones and the Emperor's Tomb      June 11, 2019
# 1                       Tom Clancy's Splinter Cell      June 11, 2019
# 2                              Armed and Dangerous      June 11, 2019
# 3                      Sphinx and the Cursed Mummy      June 11, 2019
# 4     Tom Clancy's Splinter Cell: Pandora Tomorrow      June 11, 2019
# ...                                            ...                ...
# 5061                     Dragon Ball: The Breakers   October 14, 2022
# 5062                                     Recompile    August 19, 2021
# 5063             Dungeons & Dragons: Dark Alliance      June 22, 2021
# 5064                 Override 2: Super Mech League  December 22, 2020
# 5065         Werewolf: The Apocalypse - Earthblood   February 4, 2021
#
#      Metascore Userscore
# 0          tbd       tbd
# 1          tbd       tbd
# 2          tbd       tbd
# 3          tbd       tbd
# 4          tbd       tbd
# ...        ...       ...
# 5061        59       tbd
# 5062        58       4.4
# 5063        58       4.7
# 5064        58       tbd
# 5065        58       4.6
#
# [5066 rows x 4 columns]

# %%
df_metacritic.shape
# Out:
# (5066, 4)

# %% [markdown]
# # Tratamento dos nomes dos jogos para posterior merge das bases de dados

# %%
# como os dados vêm de diferentes fontes, muitos dos jogos podem ter nomes escritos de maneira diferente nas diferentes
# bases de dados.

# a ideia é eliminar qualquer tipo de caráctere especial e colocar todas as letras em maiúsculo a fim de igualar os nomes
# dos jogos.

# %% [markdown]
# Eliminando os carácteres especiais com expressões regulares (Regex)

# %%
# para a tabela de jogos do Game Pass:

df_gamepass['Game'] = df_gamepass['Game'].replace(r'[' + string.punctuation +']', '', regex= True).str.upper()
df_gamepass.head()
# Out:
# 0                      Game     System xCloud       Status     Added Removed  \
# 1        PERSONA 3 PORTABLE  Xbox / PC    Yes  Coming Soon  Jan 2023     NaN
# 2          PERSONA 4 GOLDEN  Xbox / PC    Yes  Coming Soon  Jan 2023     NaN
# 3              HIGH ON LIFE  Xbox / PC    Yes  Coming Soon  Dec 2022     NaN
# 4          HELLO NEIGHBOR 2  Xbox / PC    Yes  Coming Soon  Dec 2022     NaN
# 5  WARHAMMER 40000 DARKTIDE  Xbox / PC    Yes  Coming Soon  Nov 2022     NaN
#
# 0 Months   Release    Age Metacritic Completion     Genre (Giantbomb)  \
# 1  -2.63  Nov 2009  13.22         89       65.5          Role-Playing
# 2  -2.63  Jun 2012  10.61         90       68.5                   NaN
# 3  -1.41  Dec 2022   0.00        NaN        NaN  First-Person Shooter
# 4  -1.18  Dec 2022   0.00        NaN        NaN     Strategy / Puzzle
# 5  -0.99  Nov 2022   0.00        NaN        NaN                Action
#
# 0 Xbox Series X|S Owner Notes  ESRB  \
# 1             NaN         NaN     M
# 2             NaN         NaN     M
# 3             NaN         NaN     M
# 4             NaN         NaN  E10+
# 5       Exclusive         NaN    RP
#
# 0                           ESRB Content Descriptors Public Notes Retail
# 1  Blood, Language, Partial Nudity, Sexual Themes...          NaN    NaN
# 2  Alcohol Reference, Animated Blood, Language, P...          NaN    NaN
# 3  Violence, Blood, Sexual Themes, Use of Drugs, ...          NaN    NaN
# 4                                      Mild Violence          NaN    NaN
# 5                                                NaN          NaN    NaN

# %%
# para a biblioteca de jogos de Xbox:

df_xbox_games['name'] = df_xbox_games['name'].replace(r'[' + string.punctuation +']', '', regex= True).str.upper()
df_xbox_games.head()
# Out:
#                     name              genre(s)       developer(s)  \
# 0  0 DAY ATTACK ON EARTH               Shooter              Gulti
# 1            007 LEGENDS  First-person shooter            Eurocom
# 2  007 QUANTUM OF SOLACE  First-person shooter           Treyarch
# 3           0D BEAT DROP       Puzzle & Trivia       Cyclone Zero
# 4               1 VS 100                 Party  Xbox Game Studios
#
#         publisher(s)   releasedate  \
# 0        Square Enix  Dec 23, 2009
# 1         Activision  Oct 16, 2012
# 2         Activision   Nov 4, 2008
# 3   Arc System Works  Nov 11, 2009
# 4  Xbox Game Studios  Nov 19, 2009
#
#                                               addons
# 0  ['Xbox Live Arcade', 'Xbox One Backward Compat...
# 1                                                 []
# 2                                                 []
# 3                               ['Xbox Live Arcade']
# 4                               ['Xbox Live Arcade']

# %%
# para os dados oriundos do True Achievements:

df_true_achievements['Name'] = df_true_achievements['Name'].replace(r'[' + string.punctuation +']', '', regex= True).str.upper()
df_true_achievements.head()
# Out:
#                         Name TA_Score Gamerscore Ratio  Gamers  Comp %  \
# 0  ZAZEN ZEN MEDITATION GAME    3,234      1,000  3.23     199     3.5
# 1                      IDARB    1,430      1,000  1.43  93,605    22.9
# 2               SINUCAATTACK    1,018      1,000  1.02   5,294    93.8
# 3                   OBSERVER    2,055      1,000  2.06  12,124     7.0
# 4                  0 DEGREES    1,064      1,000  1.06   2,645    75.9
#
#      Comp time Rating
# 0          NaN      -
# 1    1-2 hours    2.7
# 2  0-0.5 hours    1.9
# 3  10-12 hours    3.4
# 4    1-2 hours    2.1

# %%
# para os dados dos jogos oriundos do agregador Metacritic:

df_metacritic['Name'] = df_metacritic['Name'].replace(r'[' + string.punctuation +']', '', regex= True).str.upper()
df_metacritic.head()
# Out:
#                                          Name   Release date Metascore  \
# 0         INDIANA JONES AND THE EMPERORS TOMB  June 11, 2019       tbd
# 1                   TOM CLANCYS SPLINTER CELL  June 11, 2019       tbd
# 2                         ARMED AND DANGEROUS  June 11, 2019       tbd
# 3                 SPHINX AND THE CURSED MUMMY  June 11, 2019       tbd
# 4  TOM CLANCYS SPLINTER CELL PANDORA TOMORROW  June 11, 2019       tbd
#
#   Userscore
# 0       tbd
# 1       tbd
# 2       tbd
# 3       tbd
# 4       tbd

# %% [markdown]
# # Merge de todas as bases de dados

# %%
# merge dos dataframes do Game Pass e do True Achivements:

gamepass_database = pd.merge(left= df_gamepass[['Game', 'System', 'Status', 'Added', 'Removed', 'Genre (Giantbomb)','ESRB',
                            'ESRB Content Descriptors']], right= df_true_achievements, how= 'left', 
                             left_on= ['Game'], right_on= ['Name']
)

# %%
gamepass_database.drop(['Name'], axis= 1, inplace= True)
gamepass_database.head()
# Out:
#                        Game     System       Status     Added Removed  \
# 0        PERSONA 3 PORTABLE  Xbox / PC  Coming Soon  Jan 2023     NaN
# 1          PERSONA 4 GOLDEN  Xbox / PC  Coming Soon  Jan 2023     NaN
# 2              HIGH ON LIFE  Xbox / PC  Coming Soon  Dec 2022     NaN
# 3          HELLO NEIGHBOR 2  Xbox / PC  Coming Soon  Dec 2022     NaN
# 4  WARHAMMER 40000 DARKTIDE  Xbox / PC  Coming Soon  Nov 2022     NaN
#
#       Genre (Giantbomb)  ESRB  \
# 0          Role-Playing     M
# 1                   NaN     M
# 2  First-Person Shooter     M
# 3     Strategy / Puzzle  E10+
# 4                Action    RP
#
#                             ESRB Content Descriptors    TA_Score Gamerscore  \
# 0  Blood, Language, Partial Nudity, Sexual Themes...  Unreleased          -
# 1  Alcohol Reference, Animated Blood, Language, P...  Unreleased          -
# 2  Violence, Blood, Sexual Themes, Use of Drugs, ...  Unreleased          -
# 3                                      Mild Violence  Unreleased          -
# 4                                                NaN  Unreleased          -
#
#   Ratio Gamers  Comp % Comp time Rating
# 0     -      0     0.0       NaN      -
# 1     -      0     0.0       NaN      -
# 2     -      0     0.0       NaN      -
# 3     -      0     0.0       NaN      -
# 4     -      0     0.0       NaN      -

# %%
# merge do dataframe do Game Pass com o de jogos da biblioteca do Xbox:

gamepass_database = pd.merge(left= gamepass_database, right= df_xbox_games[['name', 'developer(s)',
                            'publisher(s)', 'addons']], how= 'left', left_on= ['Game'], right_on= ['name']
)

# %%
gamepass_database.drop(['name'], axis= 1, inplace= True)
gamepass_database.head()
# Out:
#                        Game     System       Status     Added Removed  \
# 0        PERSONA 3 PORTABLE  Xbox / PC  Coming Soon  Jan 2023     NaN
# 1          PERSONA 4 GOLDEN  Xbox / PC  Coming Soon  Jan 2023     NaN
# 2              HIGH ON LIFE  Xbox / PC  Coming Soon  Dec 2022     NaN
# 3          HELLO NEIGHBOR 2  Xbox / PC  Coming Soon  Dec 2022     NaN
# 4  WARHAMMER 40000 DARKTIDE  Xbox / PC  Coming Soon  Nov 2022     NaN
#
#       Genre (Giantbomb)  ESRB  \
# 0          Role-Playing     M
# 1                   NaN     M
# 2  First-Person Shooter     M
# 3     Strategy / Puzzle  E10+
# 4                Action    RP
#
#                             ESRB Content Descriptors    TA_Score Gamerscore  \
# 0  Blood, Language, Partial Nudity, Sexual Themes...  Unreleased          -
# 1  Alcohol Reference, Animated Blood, Language, P...  Unreleased          -
# 2  Violence, Blood, Sexual Themes, Use of Drugs, ...  Unreleased          -
# 3                                      Mild Violence  Unreleased          -
# 4                                                NaN  Unreleased          -
#
#   Ratio Gamers  Comp % Comp time Rating    developer(s) publisher(s)  \
# 0     -      0     0.0       NaN      -           Atlus         Sega
# 1     -      0     0.0       NaN      -           Atlus         Sega
# 2     -      0     0.0       NaN      -             NaN          NaN
# 3     -      0     0.0       NaN      -  Dynamic Pixels    TinyBuild
# 4     -      0     0.0       NaN      -        Fatshark     Fatshark
#
#                               addons
# 0                               ['']
# 1                               ['']
# 2                                NaN
# 3                               ['']
# 4  ['Optimized for Xbox Series X/S']

# %%
# por fim, merge entre o dataframe do Game Pass e do Metacritic:

gamepass_database = pd.merge(left= gamepass_database, right= df_metacritic, how= 'left', left_on= ['Game'],
                             right_on= ['Name']
)

# %%
gamepass_database.drop(['Name'], axis= 1, inplace= True)
gamepass_database.head()
# Out:
#                        Game     System       Status     Added Removed  \
# 0        PERSONA 3 PORTABLE  Xbox / PC  Coming Soon  Jan 2023     NaN
# 1          PERSONA 4 GOLDEN  Xbox / PC  Coming Soon  Jan 2023     NaN
# 2              HIGH ON LIFE  Xbox / PC  Coming Soon  Dec 2022     NaN
# 3          HELLO NEIGHBOR 2  Xbox / PC  Coming Soon  Dec 2022     NaN
# 4  WARHAMMER 40000 DARKTIDE  Xbox / PC  Coming Soon  Nov 2022     NaN
#
#       Genre (Giantbomb)  ESRB  \
# 0          Role-Playing     M
# 1                   NaN     M
# 2  First-Person Shooter     M
# 3     Strategy / Puzzle  E10+
# 4                Action    RP
#
#                             ESRB Content Descriptors    TA_Score Gamerscore  \
# 0  Blood, Language, Partial Nudity, Sexual Themes...  Unreleased          -
# 1  Alcohol Reference, Animated Blood, Language, P...  Unreleased          -
# 2  Violence, Blood, Sexual Themes, Use of Drugs, ...  Unreleased          -
# 3                                      Mild Violence  Unreleased          -
# 4                                                NaN  Unreleased          -
#
#    ... Gamers Comp %  Comp time Rating    developer(s) publisher(s)  \
# 0  ...      0    0.0        NaN      -           Atlus         Sega
# 1  ...      0    0.0        NaN      -           Atlus         Sega
# 2  ...      0    0.0        NaN      -             NaN          NaN
# 3  ...      0    0.0        NaN      -  Dynamic Pixels    TinyBuild
# 4  ...      0    0.0        NaN      -        Fatshark     Fatshark
#
#                               addons Release date Metascore Userscore
# 0                               ['']          NaN       NaN       NaN
# 1                               ['']          NaN       NaN       NaN
# 2                                NaN          NaN       NaN       NaN
# 3                               ['']          NaN       NaN       NaN
# 4  ['Optimized for Xbox Series X/S']          NaN       NaN       NaN
#
# [5 rows x 21 columns]

# %%
gamepass_database.shape
# Out:
# (1197, 21)

# %% [markdown]
# # Alguns tratamentos para exportar a base de dados do Game Pass

# %%
gamepass_database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1197 entries, 0 to 1196
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Game                      1197 non-null   object
#  1   System                    1196 non-null   object
#  2   Status                    1196 non-null   object
#  3   Added                     1197 non-null   object
#  4   Removed                   646 non-null    object
#  5   Genre (Giantbomb)         1192 non-null   object
#  6   ESRB                      678 non-null    object
#  7   ESRB Content Descriptors  594 non-null    object
#  8   TA_Score                  926 non-null    object
#  9   Gamerscore                926 non-null    object
#  10  Ratio                     926 non-null    object
#  11  Gamers                    926 non-null    object
#  12  Comp %                    926 non-null    float64
#  13  Comp time                 846 non-null    object
#  14  Rating                    926 non-null    object
#  15  developer(s)              733 non-null    object
#  16  publisher(s)              733 non-null    object
#  17  addons                    733 non-null    object
#  18  Release date              753 non-null    object
#  19  Metascore                 753 non-null    object
#  20  Userscore                 753 non-null    object
# dtypes: float64(1), object(20)
# memory usage: 205.7+ KB

# %%
# a fim de padronizar os nomes das colunas, faz-se a sua renomeação:

gamepass_database.columns = ['game', 'system', 'status', 'added', 'removed', 'genre', 'esrb', 'esrb content', 'ta_score', 'gamerscore', 'ratio',
                            'gamers', 'comp_%', 'comp_time', 'rating', 'developer', 'publisher', 'addons', 'release_date', 'metascore', 'userscore']

# %%
gamepass_database.head()
# Out:
#                        game     system       status     added removed  \
# 0        PERSONA 3 PORTABLE  Xbox / PC  Coming Soon  Jan 2023     NaN
# 1          PERSONA 4 GOLDEN  Xbox / PC  Coming Soon  Jan 2023     NaN
# 2              HIGH ON LIFE  Xbox / PC  Coming Soon  Dec 2022     NaN
# 3          HELLO NEIGHBOR 2  Xbox / PC  Coming Soon  Dec 2022     NaN
# 4  WARHAMMER 40000 DARKTIDE  Xbox / PC  Coming Soon  Nov 2022     NaN
#
#                   genre  esrb  \
# 0          Role-Playing     M
# 1                   NaN     M
# 2  First-Person Shooter     M
# 3     Strategy / Puzzle  E10+
# 4                Action    RP
#
#                                         esrb content    ta_score gamerscore  \
# 0  Blood, Language, Partial Nudity, Sexual Themes...  Unreleased          -
# 1  Alcohol Reference, Animated Blood, Language, P...  Unreleased          -
# 2  Violence, Blood, Sexual Themes, Use of Drugs, ...  Unreleased          -
# 3                                      Mild Violence  Unreleased          -
# 4                                                NaN  Unreleased          -
#
#    ... gamers comp_%  comp_time rating       developer  publisher  \
# 0  ...      0    0.0        NaN      -           Atlus       Sega
# 1  ...      0    0.0        NaN      -           Atlus       Sega
# 2  ...      0    0.0        NaN      -             NaN        NaN
# 3  ...      0    0.0        NaN      -  Dynamic Pixels  TinyBuild
# 4  ...      0    0.0        NaN      -        Fatshark   Fatshark
#
#                               addons release_date metascore userscore
# 0                               ['']          NaN       NaN       NaN
# 1                               ['']          NaN       NaN       NaN
# 2                                NaN          NaN       NaN       NaN
# 3                               ['']          NaN       NaN       NaN
# 4  ['Optimized for Xbox Series X/S']          NaN       NaN       NaN
#
# [5 rows x 21 columns]

# %%
# por questões de organização e estética, reorganiza-se algumas colunas:

gamepass_database = gamepass_database[['game', 'system', 'status', 'release_date', 'added', 'removed', 'genre', 'developer', 'publisher', 'esrb', 'esrb content', 
                                      'addons', 'ta_score', 'gamerscore', 'ratio', 'gamers', 'comp_%', 'comp_time', 'rating', 'metascore', 'userscore']]

# %% [markdown]
# # Exportando o dataframe

# %%
gamepass_database.to_csv('database_gamepass.csv', index= False)
